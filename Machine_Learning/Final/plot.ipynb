# %%
import matplotlib.pyplot as plt
import numpy as np

# 定義指標名稱
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']

# 各種算法的分數
rf_scores = [0.85, 0.82, 0.92, 0.87]
xgboost_scores = [0.86, 0.82, 0.94, 0.88]
nn_scores = [0.81, 0.73, 0.91, 0.81]

# 定義顏色，對應每個算法
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # 藍色 (RF), 橙色 (XGBoost), 綠色 (Neural Network)

# 設定圖形大小
plt.figure(figsize=(10, 6))

# 繪製每個算法的分數
plt.plot(metrics, rf_scores, label='RF', color=colors[0], marker='o')
plt.plot(metrics, xgboost_scores, label='XGBoost', color=colors[1], marker='o')
plt.plot(metrics, nn_scores, label='Neural Network', color=colors[2], marker='o')

# # 在每個點上標註數值
# for i, score in enumerate(rf_scores):
#     plt.text(metrics[i], score, f'{score:.2f}', color=colors[0], ha='center', va='bottom', fontsize=10)

# for i, score in enumerate(xgboost_scores):
#     plt.text(metrics[i], score, f'{score:.2f}', color=colors[1], ha='center', va='bottom', fontsize=10)

# for i, score in enumerate(nn_scores):
#     plt.text(metrics[i], score, f'{score:.2f}', color=colors[2], ha='center', va='bottom', fontsize=10)

# 設定標題和軸標籤
plt.title('Performance for Different Algorithms -- KOI table')
plt.xlabel('Metric')
plt.ylabel('Score')
plt.ylim(0.6, 0.95)

# 顯示圖例
plt.legend()

# 顯示圖表
plt.grid(True)
plt.show()

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']
algorithms = ['Random Forest','XGBoost','Neural Network']

values = np.array([
    [0.85,0.86,0.81],
    [0.82,0.82,0.73],
    [0.92,0.94,0.91],
    [0.87,0.88,0.81],
])

x = np.arange(len(metrics))
width = 0.2

fig,ax = plt.subplots(figsize=(10,6))

for i, algorithm in enumerate(algorithms):
    bars = ax.bar(x+i*width - width,values[:,i],width,label=algorithm)

    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2f}', ha='center',va='bottom',fontsize=10)

ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('KOI table')

ax.set_xticks(x)
ax.set_xticklabels(metrics)

ax.legend()

plt.tight_layout()
plt.show()

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']
algorithms = ['Random Forest','XGBoost','Neural Network']

values = np.array([
    [0.76,0.80,0.75],
    [0.69,0.79,0.75],
    [0.94,0.82,0.77],
    [0.80,0.81,0.76],
])

x = np.arange(len(metrics))
width = 0.2

fig,ax = plt.subplots(figsize=(10,6))

for i, algorithm in enumerate(algorithms):
    bars = ax.bar(x+i*width - width,values[:,i],width,label=algorithm)

    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2f}', ha='center',va='bottom',fontsize=10)

ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Light curve')

ax.set_xticks(x)
ax.set_xticklabels(metrics)

ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 定義指標名稱
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']

# 各種算法的分數
rf_scores = [0.76, 0.69, 0.94, 0.80]
xgboost_scores = [0.80, 0.81, 0.79, 0.82]
nn_scores = [0.75, 0.75, 0.77, 0.76]

# 定義顏色，對應每個算法
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # 藍色 (RF), 橙色 (XGBoost), 綠色 (Neural Network)

# 設定圖形大小
plt.figure(figsize=(10, 6))

# 繪製每個算法的分數
plt.plot(metrics, rf_scores, label='RF', color=colors[0], marker='o')
plt.plot(metrics, xgboost_scores, label='XGBoost', color=colors[1], marker='o')
plt.plot(metrics, nn_scores, label='Neural Network', color=colors[2], marker='o')

# 在每個點上標註數值
# for i, score in enumerate(rf_scores):
#     plt.text(metrics[i], score, f'{score:.2f}', color=colors[0], ha='center', va='bottom', fontsize=10)

# for i, score in enumerate(xgboost_scores):
#     plt.text(metrics[i], score, f'{score:.2f}', color=colors[1], ha='center', va='bottom', fontsize=10)

# for i, score in enumerate(nn_scores):
#     plt.text(metrics[i], score, f'{score:.2f}', color=colors[2], ha='center', va='bottom', fontsize=10)

# 設定標題和軸標籤
plt.title('Performance for Different Algorithms -- Light curve')
plt.xlabel('Metric')
plt.ylabel('Score')
plt.ylim(0.6,0.95)
# 顯示圖例
plt.legend()

# 顯示圖表
plt.grid(True)
plt.show()
