# %%
pip install matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('lab2_advanced_training.csv')
advanced_testing_data = pd.read_csv('lab2_advanced_testing.csv')

# %%
import numpy as np
import matplotlib.pyplot as plt

# 随机生成特征数据
X = df.iloc[:,:-1]

# 随机生成类别（0 或 1）
y = df.iloc[:,-1:]
num_samples = 50#X.shape[0]  # 样本数量
  # 特征数量
# # 定义颜色
# colors = plt.cm.viridis(np.linspace(0, 1, num_features))

# 创建图形
plt.figure(figsize=(10, 6))

df = df.sample(n=num_samples)
num_features = df.shape[1]
fig, axs = plt.subplots(nrows=num_features, ncols=1, figsize=(8, 4 * num_features))

# 遍历每个特征并绘制图形
for i, feature in enumerate(df):
    axs[i].scatter(df[feature][df['hospital_death'] == 0], df[feature][df['hospital_death'] == 0], 
                   marker='o', color='blue', label='Class 0', alpha=0.5)

    axs[i].scatter(df[feature][df['hospital_death'] == 1], df[feature][df['hospital_death'] == 1], 
                   marker='*', color='red', label='Class 1', alpha=0.5)

    axs[i].set_title(f'Scatter Plot of {feature}')
    axs[i].set_xlabel(feature)
    axs[i].set_ylabel('Random Y Coordinate')
    axs[i].legend()
    axs[i].grid()

plt.tight_layout()
plt.show()
